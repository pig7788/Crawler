# %%
import requests, math, re, sys, time, json
from bs4 import  BeautifulSoup as bs

# %%
rs = requests.session()
res = rs.get('http://vacation.eztravel.com.tw/pkgfrn/results/TPE/80?fullStatus=NONE')
soup = bs(res.text, "lxml")

# %%
count  = soup.select('.v-line')[0].text.split(' ')
print count[1]
page = int(math.ceil(float(count[1]) / 18))
print page
# Out:
# 109
# 7

# %%
urlFormat = 'http://vacation.eztravel.com.tw/pkgfrn/results/TPE/80/{}?&fullStatus=NONE'
with open('E:\\BigData\\Project\\Travel\\EZTravel\\Japan\\Link\\bid_list_for_EZtravel_in_Kyushu.txt','w') as f:
    for pageNum in range(1, page + 1):
        url = urlFormat.format(pageNum)
        res2 = rs.get(url)
        soup1 = bs(res2.text, "lxml")
        list_table = soup1.select('div#listTable')[0]
        for items in list_table.select('div.list-box.mainLinkBox'):
            f.write('http://vacation.eztravel.com.tw/pkgfrn/' + items.select('a')[0]['href'].split('/pkgfrn/')[1] + '\n')

# %%
dicCheck = {} #宣告一個dic，稍後會將檔名(Key)跟網址(Value)一一放入
num = 0
for bid_url in open('E:\\BigData\\Project\\Travel\\EZTravel\\Japan\\Link\\bid_list_for_EZtravel_in_Kyushu.txt','r'): #讀連結檔
    num += 1
    splitStr = bid_url.split('/') #將網址切割，並且丟入splitStr這個List裡
    linkName = splitStr[5].strip() + "_" + splitStr[6].strip() #將List[index]對應到的元素，以字串型式組合成dataNmae
    #用商品編號當作檔名
    if linkName not in dicCheck:
        print 'No.' + str(num) + ', ' + linkName +  ' is new, and added in dicCheck.'
        dicCheck[linkName] = bid_url
    else:
        print 'No.' + str(num) + ', ' + linkName + ' is existed, and not added in dicCheck.'
        print linkName, dicCheck[linkName] #若有重複，則print出重複的Key跟Value
# Out:
# No.1, FRN0000013799_20160629 is new, and added in dicCheck.
# No.2, FRN0000013800_20160617 is new, and added in dicCheck.
# No.3, FRN0000013550_20160629 is new, and added in dicCheck.
# No.4, FRN0000013638_20160617 is new, and added in dicCheck.
# No.5, FRN0000013798_20160605 is new, and added in dicCheck.
# No.6, VDR0000001888_OKA04160605H is new, and added in dicCheck.
# No.7, VDR0000001846_16JO606BRA is new, and added in dicCheck.
# No.8, VDR0000001279_A0606D4GE is new, and added in dicCheck.
# No.9, VDR0000007986_OKA04GE60616G_6382 is new, and added in dicCheck.
# No.10, VDR0000001838_NKB060604BR6 is new, and added in dicCheck.
# No.11, VDR0000001888_OKA04160712N is new, and added in dicCheck.
# No.12, VDR0000007986_OKA04GE60616G_2368 is new, and added in dicCheck.
# No.13, VDR0000007986_OKA04BR61216B_6728 is new, and added in dicCheck.
# No.14, VDR0000007986_OKA04BR61316O_6728 is new, and added in dicCheck.
# No.15, VDR0000007986_OKA04IT62116I_5353 is new, and added in dicCheck.
# No.16, VDR0000001846_16JO613BRZ is new, and added in dicCheck.
# No.17, VDR0000001279_A0606B4CI is new, and added in dicCheck.
# No.18, VDR0000001943_OKA04BR6620H is new, and added in dicCheck.
# No.19, VDR0000001913_OKA04CI160606B is new, and added in dicCheck.
# No.20, FRN0000013990_20160622 is new, and added in dicCheck.
# No.21, VDR0000001279_A0621A4GE is new, and added in dicCheck.
# No.22, VDR0000001843_OKAGE16062204A is new, and added in dicCheck.
# No.23, VDR0000007986_OKA04GE61416G_6081 is new, and added in dicCheck.
# No.24, VDR0000001975_OKA04160615TD is new, and added in dicCheck.
# No.25, FRN0000013659_20160606 is new, and added in dicCheck.
# No.26, VDR0000001843_OKAGE16060604A is new, and added in dicCheck.
# No.27, VDR0000001838_NKD053104BR6 is new, and added in dicCheck.
# No.28, VDR0000001888_OKA04160619L is new, and added in dicCheck.
# No.29, VDR0000001897_OKACI60615GD is new, and added in dicCheck.
# No.30, VDR0000001846_16JO621BR is new, and added in dicCheck.
# No.31, VDR0000001943_OKA04CI6613D is new, and added in dicCheck.
# No.32, VDR0000001279_A0623B4CI is new, and added in dicCheck.
# No.33, VDR0000007986_OKA04CI72916C_6750 is new, and added in dicCheck.
# No.34, VDR0000007986_OKA04BR72916B_6750 is new, and added in dicCheck.
# No.35, VDR0000001914_OKA04160607A is new, and added in dicCheck.
# No.36, VDR0000001846_16JO620BRQ is new, and added in dicCheck.
# No.37, VDR0000001914_OKA04160605A is new, and added in dicCheck.
# No.38, VDR0000001888_OKA04160620A is new, and added in dicCheck.
# No.39, FRN0000010017_20160621 is new, and added in dicCheck.
# No.40, FRN0000013935_20160818 is new, and added in dicCheck.
# No.41, VDR0000001943_OKA04CI6621C is new, and added in dicCheck.
# No.42, VDR0000001846_16JO611CIN is new, and added in dicCheck.
# No.43, VDR0000007986_OKA04BR60616O_6693 is new, and added in dicCheck.
# No.44, VDR0000007986_OKA04BR61216B_6693 is new, and added in dicCheck.
# No.45, VDR0000001279_A0622A4GE is new, and added in dicCheck.
# No.46, VDR0000007986_OKA04BR60616O_6473 is new, and added in dicCheck.
# No.47, VDR0000007986_OKA04BR61216B_6473 is new, and added in dicCheck.
# No.48, VDR0000001975_OKA04160614TC is new, and added in dicCheck.
# No.49, VDR0000001838_NKO062004CI6C is new, and added in dicCheck.
# No.50, VDR0000001925_OKCNC460610A is new, and added in dicCheck.
# No.51, VDR0000001888_OKA04160606J is new, and added in dicCheck.
# No.52, VDR0000001888_OKA04160617B is new, and added in dicCheck.
# No.53, VDR0000001897_OKACI60713GD is new, and added in dicCheck.
# No.54, VDR0000001925_OKCMC460705A is new, and added in dicCheck.
# No.55, VDR0000001925_OKABCD60706A is new, and added in dicCheck.
# No.56, VDR0000001925_OKCTF460626A is new, and added in dicCheck.
# No.57, VDR0000001843_OKAGE16062704B is new, and added in dicCheck.
# No.58, VDR0000001897_OKACI60609GD is new, and added in dicCheck.
# No.59, VDR0000001925_OKAEFG60703A is new, and added in dicCheck.
# No.60, VDR0000001888_OKA04160701A is new, and added in dicCheck.
# No.61, VDR0000001888_OKA04160703L is new, and added in dicCheck.
# No.62, FRN0000013994_20160706 is new, and added in dicCheck.
# No.63, VDR0000001838_NKO061204BR6 is new, and added in dicCheck.
# No.64, VDR0000001838_NKO080804BR6 is new, and added in dicCheck.
# No.65, VDR0000001943_OKA04BR6907J is new, and added in dicCheck.
# No.66, VDR0000007986_OKA04BR62916B_5005 is new, and added in dicCheck.
# No.67, VDR0000001914_OKA04160627B is new, and added in dicCheck.
# No.68, VDR0000001846_16JO627BRZ is new, and added in dicCheck.
# No.69, VDR0000001846_16JO627CIB is new, and added in dicCheck.
# No.70, VDR0000001838_NKO060404CI6B is new, and added in dicCheck.
# No.71, VDR0000001838_NKO070504CI6C is new, and added in dicCheck.
# No.72, VDR0000001925_OKCSC460711A is new, and added in dicCheck.
# No.73, VDR0000001897_OKACI60603GH is new, and added in dicCheck.
# No.74, VDR0000001838_NKO062604CI6 is new, and added in dicCheck.
# No.75, VDR0000001925_OKBWVA60711B is new, and added in dicCheck.
# No.76, FRN0000014076_20160628 is new, and added in dicCheck.
# No.77, VDR0000001913_OKA04CI160811BZ is new, and added in dicCheck.
# No.78, VDR0000001913_OKA05AE160819T is new, and added in dicCheck.
# No.79, FRN0000013936_20160821 is new, and added in dicCheck.
# No.80, VDR0000001897_OKACI60801D2 is new, and added in dicCheck.
# No.81, VDR0000001943_OKA04BR6620A is new, and added in dicCheck.
# No.82, VDR0000001943_OKA04BR6704B is new, and added in dicCheck.
# No.83, VDR0000001943_OKA04BR6706A is new, and added in dicCheck.
# No.84, VDR0000001897_OKACI60611GH is new, and added in dicCheck.
# No.85, VDR0000001975_OKA04160628TB is new, and added in dicCheck.
# No.86, VDR0000001897_OKACI60821D2 is new, and added in dicCheck.
# No.87, VDR0000001888_OKA04160604C is new, and added in dicCheck.
# No.88, FRN0000011599_20160608 is new, and added in dicCheck.
# No.89, VDR0000001846_16JO626CIA is new, and added in dicCheck.
# No.90, VDR0000001888_OKA04160701J is new, and added in dicCheck.
# No.91, VDR0000001838_NKO062804CI6 is new, and added in dicCheck.
# No.92, VDR0000001843_OKACI16070504G is new, and added in dicCheck.
# No.93, FRN0000014087_20160712 is new, and added in dicCheck.
# No.94, VDR0000001897_OKACI60816D2 is new, and added in dicCheck.
# No.95, FRN0000013992_20160714 is new, and added in dicCheck.
# No.96, VDR0000001846_16JO701BR is new, and added in dicCheck.
# No.97, VDR0000001897_OKACI60801GH is new, and added in dicCheck.
# No.98, VDR0000001888_OKA04160607M is new, and added in dicCheck.
# No.99, VDR0000001846_16JO721CI is new, and added in dicCheck.
# No.100, VDR0000001838_NKO071904CI6 is new, and added in dicCheck.
# No.101, VDR0000001843_OKACI16060504G is new, and added in dicCheck.
# No.102, VDR0000001838_NKO060504CI6P is new, and added in dicCheck.
# No.103, VDR0000001888_OKA04160706C is new, and added in dicCheck.
# No.104, VDR0000001846_16JO707CIA is new, and added in dicCheck.
# No.105, VDR0000001888_OKA04160706M is new, and added in dicCheck.
# No.106, VDR0000001843_OKACI16060504E is new, and added in dicCheck.
# No.107, VDR0000001843_OKACI16060405G is new, and added in dicCheck.
# No.108, VDR0000001838_NKO060405CI6P is new, and added in dicCheck.
# No.109, VDR0000001888_OKA04160620J is new, and added in dicCheck.

# %%
### 印出字典的key與value########
def PrintKeyValue(dic_in):
    for key, value in dic_in.iteritems() :
        print key, ':', value

# %%
eachTravel = [] #放置所有細項資料於旅行方案集合
totalTravel = {} #放置所有的旅行方案於總集合
totalCount = 0
errorCount = 0
with open('E:\\BigData\\Project\\Travel\\EZTravel\\Japan\\Data\\Error\\error_list_for_EZtravel_in_Kyushu.txt', 'w') as errorFile:
    #寫error檔
    #桌電位置:E:\\BigData\\Project\\Travel\\EZTravel\\Japan\\Data\\Error\\error_list_for_EZtravel_in_Kyushu.txt
    #筆電位置:D:\\Big Data\\Project\\Travel\\EZtravel\\Japan\\Data\\Error\\error_list_for_EZtravel_in_Kyushu.txt
    for bid_url in open('E:\\BigData\\Project\\Travel\\EZTravel\\Japan\\Link\\bid_list_for_EZtravel_in_Kyushu.txt', 'r'):
        #讀連結檔
        #桌電位置:E:\\BigData\\Project\\Travel\\EZTravel\\Japan\\Link\\bid_list_for_EZtravel_in_Kyushu.txt
        #筆電位置:D:\\Big Data\\Project\\Travel\\EZtravel\\Japan\\Link\\bid_list_for_EZtravel_in_Kyushu.txt
        try: #使用try-except
            itemDetail = {} #放置所有細項資料集合
            daysTour = {} #放置day{}的value
            bid_detail = requests.get(bid_url.strip()) #讀取檔案中的連結
            soup2 = bs(bid_detail.text, "lxml") #萃取資料
            row = soup2.select('div#pkgfrnVisitHistory')[0]
            agency = soup2.select('div.container.tbShow')[0].text.strip().split()
            price = re.search('\d+', row.select('.price')[0].text) #利用正規表示法抓取價格
            plane = re.search('.\W{2,4}', row.select('div#flight-block1 span')[3].text) #利用正規表示法抓取航空公司名稱
            dayBlock = soup2.select('ol.day-block')[0]
            
            itemDetail['title'] = row.select('div.pro-title.css-td h1')[0].text #將個別資料丟入itemDetail字典中，以下相同
            itemDetail['agency'] = agency[0]
            itemDetail['prodNo'] = row.select('div.pro-id-right.css-td span')[0].text.strip() + ' ' + row.select('div.pro-id-right.css-td span')[1].text.strip()
            itemDetail['href'] = bid_url.strip()
            #因為EZtravel的網站資料較鬆散，且只有旅館跟行程有規律性，故特別獨立出來寫加入的方法
            daysTourFormat = 'day{}' #建立字串格式
            for indexTour in range(0,len(dayBlock.select('div.title-circle.title-circle-green.nth-day span'))):
                daysTourInput = daysTourFormat.format(dayBlock.select('div.title-circle.title-circle-green.nth-day span')[indexTour].text) #這邊是天數，day{1}_Tour、day{2}_Tour……
                daysTour[daysTourInput] = row.select('div.day-box h4')[indexTour].text.strip()
                #這邊是索引值，row.select('div.day-box h4')[1].text.strip()、row.select('div.day-box h4')[2].text.strip()……
            itemDetail['tour'] = daysTour
            totalCount += 1 #計算有多少筆資料丟入JSON檔中

            print '----------------------------這是分隔線----------------------------'
            print 'days: ' + dayBlock.select('div.title-circle.title-circle-green.nth-day span')[-1].text #印出當前旅行方案的旅行天數
            print 'Url: ' + bid_url.strip()
#             PrintKeyValue(daysTour)
#             PrintKeyValue(itemDetail)
            eachTravel.append(itemDetail)
            totalTravel['eachTravel'] = eachTravel

        except:
            errorCount += 1
            splitPID = bid_url.strip().split('/')
            strPID = splitPID[5].strip() + "_" + splitPID[6].strip()
            #當錯誤訊息出現時，印出是哪一筆資料出現錯誤
            print '----------------' + strPID + ' is error!!----------------'
                #將出現錯誤的資料網址，寫入txt檔中
            errorFile.write(bid_url)


with open('E:\\BigData\\Project\\Travel\\EZTravel\\Japan\\Data\\totalTravel_for_EZtravel_in_Kyushu.json', 'w') as dataFile:
    #寫最後全部資料檔
    #桌電位置:E:\\BigData\\Project\\Travel\\EZTravel\\Japan\\Data\\totalTravel_for_EZtravel_in_Kyushu.json
    #筆電位置:D:\\Big Data\\Project\\Travel\\EZtravel\\Japan\\Data\\totalTravel_for_EZtravel_in_Kyushu.json
    json.dump(totalTravel, dataFile)

print '----------------------------All datas are done!!!----------------------------'
print 'Data Quantities: ' + str(totalCount)
print 'Error Quantities: ' + str(errorCount)
# Out:
# ----------------------------這是分隔線----------------------------
# days: 3
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013799/20160629
# ----------------------------這是分隔線----------------------------
# days: 3
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013800/20160617
# ----------------------------這是分隔線----------------------------
# days: 3
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013550/20160629
# ----------------------------這是分隔線----------------------------
# days: 3
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013638/20160617
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013798/20160605
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160605H
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO606BRA
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001279/A0606D4GE
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04GE60616G_6382
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKB060604BR6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160712N
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04GE60616G_2368
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04BR61216B_6728
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04BR61316O_6728
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04IT62116I_5353
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO613BRZ
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001279/A0606B4CI
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001943/OKA04BR6620H
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001913/OKA04CI160606B
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013990/20160622
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001279/A0621A4GE
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001843/OKAGE16062204A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04GE61416G_6081
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001975/OKA04160615TD
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013659/20160606
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001843/OKAGE16060604A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKD053104BR6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160619L
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60615GD
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO621BR
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001943/OKA04CI6613D
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001279/A0623B4CI
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04CI72916C_6750
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04BR72916B_6750
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001914/OKA04160607A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO620BRQ
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001914/OKA04160605A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160620A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000010017/20160621
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013935/20160818
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001943/OKA04CI6621C
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO611CIN
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04BR60616O_6693
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04BR61216B_6693
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001279/A0622A4GE
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04BR60616O_6473
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04BR61216B_6473
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001975/OKA04160614TC
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO062004CI6C
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001925/OKCNC460610A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160606J
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160617B
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60713GD
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001925/OKCMC460705A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001925/OKABCD60706A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001925/OKCTF460626A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001843/OKAGE16062704B
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60609GD
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001925/OKAEFG60703A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160701A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160703L
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013994/20160706
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO061204BR6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO080804BR6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001943/OKA04BR6907J
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000007986/OKA04BR62916B_5005
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001914/OKA04160627B
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO627BRZ
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO627CIB
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO060404CI6B
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO070504CI6C
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001925/OKCSC460711A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60603GH
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO062604CI6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001925/OKBWVA60711B
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000014076/20160628
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001913/OKA04CI160811BZ
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001913/OKA05AE160819T
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013936/20160821
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60801D2
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001943/OKA04BR6620A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001943/OKA04BR6704B
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001943/OKA04BR6706A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60611GH
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001975/OKA04160628TB
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60821D2
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160604C
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000011599/20160608
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO626CIA
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160701J
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO062804CI6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001843/OKACI16070504G
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000014087/20160712
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60816D2
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/FRN0000013992/20160714
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO701BR
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001897/OKACI60801GH
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160607M
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO721CI
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO071904CI6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001843/OKACI16060504G
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO060504CI6P
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160706C
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001846/16JO707CIA
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160706M
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001843/OKACI16060504E
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001843/OKACI16060405G
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001838/NKO060405CI6P
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://vacation.eztravel.com.tw/pkgfrn/introduction/VDR0000001888/OKA04160620J
# ----------------------------All datas are done!!!----------------------------
# Data Quantities: 109
# Error Quantities: 0
