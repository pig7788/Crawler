# %%
import requests, math, re, time, json
from bs4 import  BeautifulSoup as bs

# %% [markdown]
# ## 抓取連結資料

# %%
rs = requests.session()
res = rs.get('http://group.ftstour.com.tw/FTS_Group_Index/IndexSearchG.aspx?ITN_AREA=0006&ITN_NATN=JP&ITN_CITY=&USE_BDT=2016/05/30&USE_EDT=2016/06/30&AIR_PT=&KEYWORD=')
soup = bs(res.text, "lxml")
with open('E:\\BigData\\Project\\Travel\\Ftstour\\Japan\\Link\\bid_list_for_Ftstour_in_Japan.txt', 'w') as fileWrite:
    for item in soup.select('div#tab td a'):
        if re.search('GroupDetail.*', item['href']) is not None:
            fileWrite.write('http://group.ftstour.com.tw/FTS_Group_Index/' + item['href'] + '\n')

# %% [markdown]
# ## 檢查連結是否有重複

# %%
def checkUrl(linkFilePath, areaName):
    check = {}
    num = 0
    checkedPathFormat = 'E:\\BigData\\Project\\Travel\\Ftstour\\Japan\\Link\\Checked\\checked_bid_list_for_Ftstour_in_{}.txt'
    checkedPath = checkedPathFormat.format(areaName)
    #上面兩行將路徑字串空格填入
    for bid_url in open(linkFilePath, 'r'): #讀取網頁
        num += 1
        strName = bid_url.strip().split('GRUP_CD=') #將最後的mgrupCd，切割成為獨立可判斷是否有重複的號碼
        firstGrupCD = re.search('\w*.\w*', strName[1].strip())
        secondGrupCD = re.search('\w*.\w*', strName[2].strip())
        linkName = firstGrupCD.group(0) + '_' + secondGrupCD.group(0)
        if linkName not in check: #判斷如果為true，則執行下列程式碼，並且存入檢查的字典
            print 'No.' + str(num) + ', ' + linkName +  ' is new, and added in check.'
            check[linkName] = bid_url
        else: #若false則印出重複的mgrupCd，以及網址
            print 'No.' + str(num) + ', ' + linkName + ' is existed, and not added in check.'
            print 'Url: ' + bid_url.strip()
    with open(checkedPath, 'w') as fileWrite: #將字典內的網址寫入檔案中
        for checked_linkName in check:
            fileWrite.write(check[checked_linkName])

# %%
checkUrl('E:\\BigData\\Project\\Travel\\Ftstour\\Japan\\Link\\bid_list_for_Ftstour_in_Japan.txt', 'Japan')
# Out:
# No.1, OKAC4160617A&M_OKAC4 is new, and added in check.
# No.2, OKAC4160615A&M_OKAC4 is new, and added in check.
# No.3, OKAA4160622A&M_OKAA4 is new, and added in check.
# No.4, OKAB4160613A&M_OKAB4 is new, and added in check.
# No.5, PLCC6160614A&M_PLCC6A-1 is new, and added in check.
# No.6, OKAA4160616A&M_OKAA4 is new, and added in check.
# No.7, OKAA4160617A&M_OKAA4 is new, and added in check.
# No.8, OKAA4160618A&M_OKAA4 is new, and added in check.
# No.9, OKAA4160624A&M_OKAA4 is new, and added in check.
# No.10, OKA4T160629A&M_OKA4T is new, and added in check.
# No.11, PLCC6160611A&M_PLCC6B-1 is new, and added in check.
# No.12, XJPCA160614A&M_XJPCA6 is new, and added in check.
# No.13, PLCC6160616A&M_PLCC6B-1 is new, and added in check.
# No.14, PLCC6160621A&M_PLCC6A-2 is new, and added in check.
# No.15, PLCC6160628A&M_PLCC6A-2 is new, and added in check.
# No.16, XJPCA160610A&M_XJPCA6 is new, and added in check.
# No.17, XJPS160623A&M_XJPS is new, and added in check.
# No.18, XJPS6160629A&M_XJPS6 is new, and added in check.
# No.19, XJPHC160630A&M_XJPHC6 is new, and added in check.
# No.20, XJPS160630A&M_XJPS is new, and added in check.
# No.21, XJPS6160612A&M_XJPS6 is new, and added in check.
# No.22, XCC6160617A&M_XCC6 is new, and added in check.
# No.23, PLCC6160618A&M_PLCC6B-1 is new, and added in check.
# No.24, PMY5-160621A_PMY5-KOJ is new, and added in check.
# No.25, XCC6160624A&M_XCC6 is new, and added in check.
# No.26, OKAB4160609A&M_OKAB4 is new, and added in check.
# No.27, OKAC4160609A&M_OKAC4 is new, and added in check.
# No.28, XJPE6160618A&M_XJPE6 is new, and added in check.
# No.29, XJPCA160621A&M_XJPCA6 is new, and added in check.
# No.30, XJPS6160622A&M_XJPS6 is new, and added in check.
# No.31, XJPE6160625A&M_XJPE6 is new, and added in check.
# No.32, PSPK5160627A&M_PSPK5 is new, and added in check.
# No.33, JFUK5160609A&M_JFUK5-161 is new, and added in check.
# No.34, PMY5-160612A_PMY5-C7 is new, and added in check.
# No.35, PLCC5160615A&M_PLCC5-A is new, and added in check.
# No.36, XJPS6160615A&M_XJPS6 is new, and added in check.
# No.37, XJPHC160616A&M_XJPHC6 is new, and added in check.
# No.38, XJPHC160623A&M_XJPHC6 is new, and added in check.
# No.39, PLCC6160623A&M_PLCC6B-2 is new, and added in check.
# No.40, PMY5-160624A_PMY5-C7 is new, and added in check.
# No.41, PLCC6160625A&M_PLCC6B-2 is new, and added in check.
# No.42, PSPK5160626A&M_PSPK5-AH is new, and added in check.
# No.43, XJPCA160628A&M_XJPCA6 is new, and added in check.
# No.44, XHNA6160612A&M_XHNA6 is new, and added in check.
# No.45, PCS-B160616A_PCS-BR5D16A4 is new, and added in check.
# No.46, PLCC5160622A&M_PLCC5-A is new, and added in check.
# No.47, PMY5-160625A_PMY5-KMIKMI is new, and added in check.
# No.48, PNGO5160625A&M_PNGO16SUMER1 is new, and added in check.
# No.49, PNGO5160629A&M_PNGO16SUMER1 is new, and added in check.
# No.50, PLCC5160629A&M_PLCC5-A is new, and added in check.
# No.51, PMY5-160630A_PMY5-KOJ is new, and added in check.
# No.52, JFUK1160609A&M_JFUK168P5D1 is new, and added in check.
# No.53, JTYA5160610A&M_JTYO5-A is new, and added in check.
# No.54, JTYA5160616A&M_JTYO5-A is new, and added in check.
# No.55, JFUK5160624A&M_JFUK1705D1 is new, and added in check.
# No.56, PNGO1160611A&M_PNGO16SPRIN4 is new, and added in check.
# No.57, PNGO1160615A&M_PNGO16SPRIN4 is new, and added in check.
# No.58, PNGO1160618A&M_PNGO16SPRIN4 is new, and added in check.
# No.59, PNGO1160624A&M_PNGO16SPRIN4 is new, and added in check.
# No.60, CIFSZ160626A&M_CIFSZ-T is new, and added in check.
# No.61, PCS5160617A&M_PCS-BR5D16B1 is new, and added in check.
# No.62, JOSA5160615A&M_JOSA5-1 is new, and added in check.
# No.63, PCS5160624A&M_PCS-BR5D16B1 is new, and added in check.
# No.64, PCS5160630B&M_PCS-BR5D16B1 is new, and added in check.
# No.65, JTYB5160623C&M_JTYO5-FSN is new, and added in check.
# No.66, JKHH5160629A&M_JKK5-2 is new, and added in check.
# No.67, JTOY5160620A&M_JTOY1705D1 is new, and added in check.
# No.68, XKIJ5160615A&M_XKIJ5 is new, and added in check.
# No.69, JTOY5160627A&M_JTOY1705D1 is new, and added in check.
# No.70, JCTA5160615A&M_JCTA5 is new, and added in check.
# No.71, JCTA5160622A&M_JCTA5 is new, and added in check.
# No.72, JOSB5160629A&M_JOSB5 is new, and added in check.
# No.73, JCTA5160617A&M_JCTA5-BR is new, and added in check.
# No.74, JCTB5160624A&M_JCTB5 is new, and added in check.
# No.75, JCTB5160630A&M_JCTB5 is new, and added in check.
# No.76, XKIJC160615A&M_XKIJCI is new, and added in check.
# No.77, PHI07160614A&M_PHI07-1606 is new, and added in check.
# No.78, PHI07160628A&M_PHI07-1606 is new, and added in check.
# No.79, PHI07160623A&M_PHI07-1606 is new, and added in check.

# %% [markdown]
# ## 計算檢查後加入的連結數量

# %%
def countCheckedUrl(areaName): #輸入旅遊行程地區名稱
    linkFileFormat = 'E:\\BigData\\Project\\Travel\\Ftstour\\Japan\\Link\\Checked\\checked_bid_list_for_Ftstour_in_{}.txt'
    linkFilePath = linkFileFormat.format(areaName)
    #以上做字串的填入
    count = 0 #計算次數
    for lines in open(linkFilePath, 'r'): #計算有多少個數量
        count += 1
    return count #回傳值

# %%
countCheckedUrl('Japan')
# Out:
# 79

# %% [markdown]
# ## 抓取旅遊方案細項資料

# %%
def get_TourInfo(areaName):
    linkFileFormat = 'E:\\BigData\\Project\\Travel\\Ftstour\\Japan\\Link\\Checked\\checked_bid_list_for_Ftstour_in_{}.txt'
    linkFilePath = linkFileFormat.format(areaName)
    savedFileFormat = 'E:\\BigData\\Project\\Travel\\Ftstour\\Japan\\Data\\totalTravel_for_Ftstour_in_{}.json'
    savedFilePath = savedFileFormat.format(areaName)
    errorFileFormat = 'E:\\BigData\\Project\\Travel\\Ftstour\\Japan\\Data\\Error\\error_bid_list_for_Ftstour_in_{}.txt'
    errorFilePath = errorFileFormat.format(areaName)
    #以上皆是路徑的字串格式填入
    eachTravel = [] #放置所有細項資料於旅行方案集合
    totalTravel = {} #放置所有的旅行方案於總集合
    totalCount = 0
    errorCount = 0
    with open(errorFilePath, 'w') as errorFile:
        for bid_url in open(linkFilePath, 'r'):
            try:
                itemDetail = {} #放置所有細項資料集合
                daysTour = {} #放置day{}的value
                bid_detail = requests.get(bid_url.strip()) #將檔案中的網址，取得連線
                soup = bs(bid_detail.text, "lxml") #取得連線後，萃取取得的程式碼
                itemDetail['title'] = soup.select('span#GroupTitle')[0].text.strip() #以下依照各個key、value丟入字典裡

                agency = re.search('\S.{5}', soup.select('title')[0].text.strip())
                itemDetail['agency'] = agency.group(0).strip()

                itemDetail['prodNo'] = soup.select('td.go-tour-td-color02')[2].text.strip()
                
                itemDetail['href'] = bid_url.strip()

                days = 0 #計算天數
                for tourContent in soup.select('td.go-everyday-td02a'): #行程內容
                    days += 1
                    daysTour['day{}'.format(days)] = tourContent.text.strip()
                itemDetail['tour'] = daysTour #將每天不同的行程，以字典方式丟入itemDetail字典內，形成itemDetail[daysTour[days]]
                totalCount += 1 #計算數量
                print '----------------------------這是分隔線----------------------------'
                print 'days: ' + str(days) #印出天數
                print 'Url: ' + bid_url.strip() #印出網址
                eachTravel.append(itemDetail) #將每次完整個旅遊方案內容加入到，eachTravel的List內
                totalTravel['eachTravel'] = eachTravel #將全部的旅遊方案，一次加入到字典裡
                
            except:
                errorCount += 1 #計算出現錯誤的數量
                splitPID = bid_url.strip().split('=') #取得PID
                strPID = splitPID[2].strip()
                print '----------------' + strPID + ' is error!!----------------'
                errorFile.write(bid_url) #將出現錯誤的網址寫入

    with open(savedFilePath, 'w') as dataFile: #將最後的旅遊方案全部寫入
        json.dump(totalTravel, dataFile)
    
    print '----------------------------All datas are done!!!----------------------------'
    print 'Data Quantities: ' + str(totalCount)
    print 'Error Quantities: ' + str(errorCount)

# %%
get_TourInfo('Japan')
# Out:
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAA4160618A&MGRUP_CD=OKAA4
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAA4160616A&MGRUP_CD=OKAA4
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAA4160617A&MGRUP_CD=OKAA4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC5160629A&MGRUP_CD=PLCC5-A
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PCS-B160616A&MGRUP_CD=PCS-BR5D16A4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PNGO5160629A&MGRUP_CD=PNGO16SUMER1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JCTB5160630A&MGRUP_CD=JCTB5
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPCA160628A&MGRUP_CD=XJPCA6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PMY5-160621A&MGRUP_CD=PMY5-KOJ-KMI
# ----------------------------這是分隔線----------------------------
# days: 7
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PHI07160614A&MGRUP_CD=PHI07-1606
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JCTA5160615A&MGRUP_CD=JCTA5
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JTYA5160616A&MGRUP_CD=JTYO5-A
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PMY5-160612A&MGRUP_CD=PMY5-C7
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPS160623A&MGRUP_CD=XJPS
# ----------------------------這是分隔線----------------------------
# days: 7
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XKIJC160615A&MGRUP_CD=XKIJCI
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPS6160612A&MGRUP_CD=XJPS6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKA4T160629A&MGRUP_CD=OKA4T
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PNGO1160618A&MGRUP_CD=PNGO16SPRIN4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PCS5160624A&MGRUP_CD=PCS-BR5D16B1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XCC6160624A&MGRUP_CD=XCC6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JFUK5160609A&MGRUP_CD=JFUK5-161
# ----------------------------這是分隔線----------------------------
# days: 6
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC6160618A&MGRUP_CD=PLCC6B-1
# ----------------------------這是分隔線----------------------------
# days: 6
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC6160616A&MGRUP_CD=PLCC6B-1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JCTB5160624A&MGRUP_CD=JCTB5
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JKHH5160629A&MGRUP_CD=JKK5-2
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JTYA5160610A&MGRUP_CD=JTYO5-A
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JTOY5160620A&MGRUP_CD=JTOY1705D1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JCTA5160617A&MGRUP_CD=JCTA5-BR
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PMY5-160630A&MGRUP_CD=PMY5-KOJ-KMI
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PCS5160617A&MGRUP_CD=PCS-BR5D16B1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPCA160614A&MGRUP_CD=XJPCA6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PNGO1160615A&MGRUP_CD=PNGO16SPRIN4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XHNA6160612A&MGRUP_CD=XHNA6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XCC6160617A&MGRUP_CD=XCC6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JTOY5160627A&MGRUP_CD=JTOY1705D1
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAC4160615A&MGRUP_CD=OKAC4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PCS5160630B&MGRUP_CD=PCS-BR5D16B1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPHC160630A&MGRUP_CD=XJPHC6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC6160628A&MGRUP_CD=PLCC6A-2
# ----------------------------這是分隔線----------------------------
# days: 7
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PHI07160628A&MGRUP_CD=PHI07-1606
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC6160621A&MGRUP_CD=PLCC6A-2
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JTYB5160623C&MGRUP_CD=JTYO5-FSN
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PSPK5160626A&MGRUP_CD=PSPK5-AH
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JOSA5160615A&MGRUP_CD=JOSA5-1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPHC160616A&MGRUP_CD=XJPHC6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PNGO1160611A&MGRUP_CD=PNGO16SPRIN4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JOSB5160629A&MGRUP_CD=JOSB5
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=CIFSZ160626A&MGRUP_CD=CIFSZ-T
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAB4160613A&MGRUP_CD=OKAB4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JFUK1160609A&MGRUP_CD=JFUK168P5D1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PMY5-160624A&MGRUP_CD=PMY5-C7
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPS160630A&MGRUP_CD=XJPS
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAC4160617A&MGRUP_CD=OKAC4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PNGO1160624A&MGRUP_CD=PNGO16SPRIN4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPE6160618A&MGRUP_CD=XJPE6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JCTA5160622A&MGRUP_CD=JCTA5
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC6160614A&MGRUP_CD=PLCC6A-1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPS6160615A&MGRUP_CD=XJPS6
# ----------------------------這是分隔線----------------------------
# days: 6
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC6160625A&MGRUP_CD=PLCC6B-2
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPS6160622A&MGRUP_CD=XJPS6
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAA4160622A&MGRUP_CD=OKAA4
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAB4160609A&MGRUP_CD=OKAB4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPE6160625A&MGRUP_CD=XJPE6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XKIJ5160615A&MGRUP_CD=XKIJ5
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PNGO5160625A&MGRUP_CD=PNGO16SUMER1
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAA4160624A&MGRUP_CD=OKAA4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=JFUK5160624A&MGRUP_CD=JFUK1705D1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC5160615A&MGRUP_CD=PLCC5-A
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPS6160629A&MGRUP_CD=XJPS6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPCA160610A&MGRUP_CD=XJPCA6
# ----------------------------這是分隔線----------------------------
# days: 6
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC6160611A&MGRUP_CD=PLCC6B-1
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC5160622A&MGRUP_CD=PLCC5-A
# ----------------------------這是分隔線----------------------------
# days: 4
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAC4160609A&MGRUP_CD=OKAC4
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PMY5-160625A&MGRUP_CD=PMY5-KMIKMI
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PSPK5160627A&MGRUP_CD=PSPK5
# ----------------------------這是分隔線----------------------------
# days: 7
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PHI07160623A&MGRUP_CD=PHI07-1606
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPCA160621A&MGRUP_CD=XJPCA6
# ----------------------------這是分隔線----------------------------
# days: 5
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=XJPHC160623A&MGRUP_CD=XJPHC6
# ----------------------------這是分隔線----------------------------
# days: 6
# Url: http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=PLCC6160623A&MGRUP_CD=PLCC6B-2
# ----------------------------All datas are done!!!----------------------------
# Data Quantities: 79
# Error Quantities: 0

# %%
res = requests.get('http://group.ftstour.com.tw/FTS_Group_Index/GroupDetail.aspx?GRUP_CD=OKAA4160616A&MGRUP_CD=OKAA4')
soup = bs(res.text, "lxml")
# print soup.select('title')[0].text.strip()
for ele in soup.select('td.go-everyday-td02a'): #tour
    print ele.text
# print soup.select('td.go-tour-td-color02')[2].text #prodNo
# agency = re.search('\S.{5}', soup.select('title')[0].text.strip()) #agency
# print agency.group(0).strip()
# print soup.select('span#GroupTitle')[0].text  #title
# Out:
# 良友旅行社
